# %%
#Toroidal magnet
import numpy as np
from astropy import units, constants
from scipy import integrate

# ─────────────────────────────────────────────────────────────────────────────
# Axion model parameters
# ─────────────────────────────────────────────────────────────────────────────

KSVZ = 1.92
DFSZ = 0.75

def g_x(C_ag, m_a):
    """Axion-photon coupling in GeV^-1, m_a in eV."""
    return 2e-10 * C_ag * m_a

# ─────────────────────────────────────────────────────────────────────────────
# Scan time
# ─────────────────────────────────────────────────────────────────────────────

s_per_year = 365.25 * 24 * 3600

def dB_to_eta(dB):
    """Convert dB backaction reduction to linear eta_A (amplitude convention)."""
    return 10**(dB / 20)

def scan_time(B0, V,
              model  = 'DFSZ',
              SNR    = 3,
              c_PU   = 0.1,
              Q      = 20e6,
              eta_A  = 0.1,
              T      = 10e-3,
              rho_DM = 0.45,
              g_ayy  = 1e-19,
              nu_min = 0.1e6,
              nu_max = 30e6):

    C_ag = DFSZ if model == 'DFSZ' else KSVZ

    common = (41e3 / s_per_year
              * (3      / SNR   )**2
              * (rho_DM / 0.45  )**2
              * (c_PU   / 0.1   )**4
              * (B0     / 16    )**4
              * (V      / 10    )**(10/3)
              * (Q      / 2e7   )
              * (10e-3  / T     )
              * (0.1    / eta_A ))

    def integrand(nu):
        if model is None:
            g = g_ayy
        else:
            ma_eV = constants.h.to('eV/Hz').value * nu
            g     = g_x(C_ag, ma_eV)
        dnu_dt = common * (g / 1e-19)**4 * (nu / 100e3)
        return 1.0 / dnu_dt

    result, _ = integrate.quad(integrand, nu_min, nu_max)
    return result / s_per_year

# ─────────────────────────────────────────────────────────────────────────────
# Comparison table
# ─────────────────────────────────────────────────────────────────────────────

print(f"{'Scenario':<40} {'Expected':>10}  {'DFSZ':>10} {'Ratio':>10}")
print("-" * 74)
scenarios = [
    (16, 10, 20e6, -20, 6.2, 'Baseline'),
    (29, 10, 20e6, -5, 3.2, 'Stronger magnet + higher noise'),
    (16, 8, 20e6, -25, 7.3, 'Lower noise + lower volume'),
    (16, 17, 2e6, -20, 10.6, 'Higher volume + lower Q'),
    (26, 10, 2e6, -20, 8.9, 'Stronger magnet + lower Q'),
]

for (B0, V, Q, eta_dB, expected, name) in scenarios:
    eta_A   = dB_to_eta(eta_dB)
    t_dfsz  = scan_time(B0, V, Q=Q, eta_A=eta_A, model='DFSZ')
    ratio  = expected/t_dfsz
    print(f"{name:<40} {expected:>10.1f} {t_dfsz:>10.2f} {ratio:>10.2f}")
# Out:
# Scenario                                   Expected        DFSZ      Ratio
# --------------------------------------------------------------------------
# Baseline                                        6.2       4.12       1.51
# Stronger magnet + higher noise                  3.2       2.15       1.49
# Lower noise + lower volume                      7.3       4.87       1.50
# Higher volume + lower Q                        10.6       7.02       1.51
# Stronger magnet + lower Q                       8.9       5.90       1.51

# %%
#Toroidal magnet 

import numpy as np
from astropy import units, constants
from scipy import integrate

# ─────────────────────────────────────────────────────────────────────────────
# Axion model parameters
# ─────────────────────────────────────────────────────────────────────────────

KSVZ = 1.92
DFSZ = 0.75

def g_x(C_ag, m_a):
    """Axion-photon coupling in GeV^-1, m_a in eV."""
    return 2e-10 * C_ag * m_a

# ─────────────────────────────────────────────────────────────────────────────
# Scan time
# ─────────────────────────────────────────────────────────────────────────────

s_per_year = 365.25 * 24 * 3600

def dB_to_eta(dB):
    """Convert dB backaction reduction to linear eta_A (amplitude convention)."""
    return 10**(dB / 20)

def scan_time(B0, V,
              model  = 'DFSZ',
              SNR    = 3,
              c_PU   = 0.1,
              Q      = 20e6,
              eta_A  = 0.1,
              T      = 10e-3,
              rho_DM = 0.45,
              g_ayy  = 1e-19,
              nu_min = 0.1e6,
              nu_max = 30e6):

    C_ag = DFSZ if model == 'DFSZ' else KSVZ

    common = (41e3 / s_per_year
              * (3      / SNR   )**2
              * (rho_DM / 0.45  )**2
              * (c_PU   / 0.1   )**4
              * (B0     / 12    )**4
              * (V      / 10    )**(10/3)
              * (Q      / 2e7   )
              * (10e-3  / T     )
              * (0.1    / eta_A ))

    def integrand(nu):
        if model is None:
            g = g_ayy
        else:
            ma_eV = constants.h.to('eV/Hz').value * nu
            g     = g_x(C_ag, ma_eV)
        dnu_dt = common * (g / 1e-19)**4 * (nu / 100e3)
        return 1.0 / dnu_dt

    result, _ = integrate.quad(integrand, nu_min, nu_max)
    return result / s_per_year

# ─────────────────────────────────────────────────────────────────────────────
# Comparison table
# ─────────────────────────────────────────────────────────────────────────────

print(f"{'Scenario':<40} {'Expected':>10}  {'DFSZ':>10} {'Ratio':>10}")
print("-" * 74)
scenarios = [
    (16, 10, 20e6, -20, 6.2, 'Baseline'),
    (29, 10, 20e6, -5, 3.2, 'Stronger magnet + higher noise'),
    (16, 8, 20e6, -25, 7.3, 'Lower noise + lower volume'),
    (16, 17, 2e6, -20, 10.6, 'Higher volume + lower Q'),
    (26, 10, 2e6, -20, 8.9, 'Stronger magnet + lower Q'),
]

for (B0, V, Q, eta_dB, expected, name) in scenarios:
    eta_A   = dB_to_eta(eta_dB)
    t_dfsz  = scan_time(B0, V, Q=Q, eta_A=eta_A, model='DFSZ')
    ratio  = expected/t_dfsz
    print(f"{name:<40} {expected:>10.1f} {t_dfsz:>10.2f} {ratio:>10.2f}")
# Out:
# Scenario                                   Expected        DFSZ      Ratio
# --------------------------------------------------------------------------
# Baseline                                        6.2       1.30       4.76
# Stronger magnet + higher noise                  3.2       0.68       4.71
# Lower noise + lower volume                      7.3       1.54       4.74
# Higher volume + lower Q                        10.6       2.22       4.77
# Stronger magnet + lower Q                       8.9       1.87       4.76

# %%
#Toroidal magnet 

import numpy as np
from astropy import units, constants
from scipy import integrate

# ─────────────────────────────────────────────────────────────────────────────
# Axion model parameters
# ─────────────────────────────────────────────────────────────────────────────

KSVZ = 1.92
DFSZ = 0.75

def g_x(C_ag, m_a):
    """Axion-photon coupling in GeV^-1, m_a in eV."""
    return 2e-10 * C_ag * m_a

# ─────────────────────────────────────────────────────────────────────────────
# Scan time
# ─────────────────────────────────────────────────────────────────────────────

s_per_year = 365.25 * 24 * 3600

def dB_to_eta(dB):
    """Convert dB backaction reduction to linear eta_A (amplitude convention)."""
    return 10**(dB / 20)

def scan_time(B0, V,
              model  = 'DFSZ',
              SNR    = 3,
              c_PU   = 0.1,
              Q      = 20e6,
              eta_A  = 0.1,
              T      = 10e-3,
              rho_DM = 0.45,
              g_ayy  = 1e-19,
              nu_min = 0.1e6,
              nu_max = 30e6):

    C_ag = DFSZ if model == 'DFSZ' else KSVZ

    common = (41e3 / s_per_year
              * (3      / SNR   )**2
              * (rho_DM / 0.45  )**2
              * (c_PU   / 0.1   )**4
              * (B0     / 12    )**4
              * (V      / 10    )**(10/3)
              * (Q      / 2e7   )
              * (10e-3  / T     )
              * (0.1    / eta_A ))

    def integrand(nu):
        if model is None:
            g = g_ayy
        else:
            ma_eV = constants.h.to('eV/Hz').value * nu
            g     = g_x(C_ag, ma_eV)
        dnu_dt = common * (g / 1e-19)**4 * (nu / 100e3)
        return 1.0 / dnu_dt

    result, _ = integrate.quad(integrand, nu_min, nu_max)
    return result / s_per_year

# ─────────────────────────────────────────────────────────────────────────────
# Comparison table
# ─────────────────────────────────────────────────────────────────────────────

print(f"{'Scenario':<40} {'Expected':>10}  {'DFSZ':>10} {'Ratio':>10}")
print("-" * 74)
scenarios = [
    (16, 10, 20e6, -20, 6.2, 'Baseline'),
    (29, 10, 20e6, -5, 3.2, 'Stronger magnet + higher noise'),
    (16, 8, 20e6, -25, 7.3, 'Lower noise + lower volume'),
    (16, 17, 2e6, -20, 10.6, 'Higher volume + lower Q'),
    (26, 10, 2e6, -20, 8.9, 'Stronger magnet + lower Q'),
]

for (B0, V, Q, eta_dB, expected, name) in scenarios:
    eta_A   = dB_to_eta(eta_dB)
    t_dfsz  = scan_time(B0, V, Q=Q, eta_A=eta_A, model='DFSZ')
    ratio  = expected/t_dfsz
    print(f"{name:<40} {expected:>10.1f} {t_dfsz:>10.2f} {ratio:>10.2f}")
# Out:
# Scenario                                   Expected        DFSZ      Ratio
# --------------------------------------------------------------------------
# Baseline                                        6.2       1.30       4.76
# Stronger magnet + higher noise                  3.2       0.68       4.71
# Lower noise + lower volume                      7.3       1.54       4.74
# Higher volume + lower Q                        10.6       2.22       4.77
# Stronger magnet + lower Q                       8.9       1.87       4.76

# %%
import numpy as np

# Given specs
base_field = 18  # Tesla
base_time_yr = 2.24  # years
freq_range = (100e3, 30e6)  # Hz

def scan_time(field_T, base_field=18, base_time_yr=2.24):
    """
    Scan time scales inversely with field strength^4
    t ∝ 1 / B^4
    """
    time_yr = base_time_yr * (base_field / field_T) ** 4
    time_days = time_yr * 365.25
    time_hrs = time_days * 24
    return time_yr, time_days, time_hrs

# Test across a range of field strengths
test_fields = [1, 5, 9, 14, 18, 25, 30, 50]

print(f"{'Field (T)':<12} {'Time (yr)':<14} ")
print("-" * 55)

for B in test_fields:
    yr, days, hrs = scan_time(B)
    print(f"{B:<12} {yr:<14.4f} ")

# Highlight the baseline
print(f"\nBaseline: {base_field} T → {base_time_yr} yr")
# Out:
# Field (T)    Time (yr)
# -------------------------------------------------------
# 1            235146.2400
# 5            376.2340
# 9            35.8400
# 14           6.1210
# 18           2.2400
# 25           0.6020
# 30           0.2903
# 50           0.0376
#
# Baseline: 18 T → 2.24 yr
